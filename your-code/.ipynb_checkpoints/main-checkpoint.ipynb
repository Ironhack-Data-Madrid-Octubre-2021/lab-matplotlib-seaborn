# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# your code here 
fitbit= pd.read_csv("../data/Fitbit2.csv")
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(12,4))
g1av=fitbit.groupby(["Months_encoded"])["Steps"].mean().plot(kind="bar"),ax=axs[0,0];
g1av.figure.savefig("../graficos/g1av.png", dpi=300)

# %%
g2m=fitbit.groupby(["Months_encoded"])["Steps"].median().plot(kind="bar");
g2m.figure.savefig("../graficos/g2m.png", dpi=300)

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
g3w=fitbit.groupby(["Work_or_Weekend"])["Steps"].mean().plot(kind="pie");
g3w.figure.savefig("../graficos/g3w.png", dpi=300)
# your code here

# %%
fitbit.groupby(["Work_or_Weekend"])["Steps"].mean() #the average steps is similar in weekends and work
# Out:
# Work_or_Weekend
# 0    10064.238095
# 1    10144.572519
# Name: Steps, dtype: float64

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(10,5))

lista=["Minutes Sedentary","Minutes Very Active","Minutes Lightly Active"]
for i in range(3):
    sns.scatterplot(x=lista[i], y="Steps",data=fitbit,ax=axs[i]);

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic= pd.read_csv("../data/titanic.csv")
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
numericas = titanic._get_numeric_data()
numericas
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
#LAS CATEGORIAS SON:'Survived', 'Pclass', 'Gender', 'SibSp', 'Parch', 'Embarked'

idx=list(titanic.columns)

# %%
titanic["Survived"].value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
titanic["Gender"].value_counts()
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %%
titanic["SibSp"].value_counts()
# Out:
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: SibSp, dtype: int64

# %%
titanic["Parch"].value_counts()
# Out:
# 0    1002
# 1     170
# 2     113
# 3       8
# 5       6
# 4       6
# 6       2
# 9       2
# Name: Parch, dtype: int64

# %%
titanic["Embarked"].value_counts()
# Out:
# S    916
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
sns.set(rc={"figure.figsize": (12.,6.)})

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,6))
sns.histplot(x=titanic.Age, bins=10,ax=axs[0])
sns.histplot(x=titanic.Age, bins=20,ax=axs[1])
sns.histplot(x=titanic.Age, bins=50,ax=axs[2])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
it determine the number of bars on the chart. bin 50 --> 50 bars
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gender1=titanic["Gender"].value_counts()
gender1.plot(kind="bar",color=["slategray","coral"])
# Out:
# <AxesSubplot:>

# %%
# Method 2 - seaborn
# your code here
sns.histplot(x=titanic.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
class1=titanic["Pclass"].value_counts()
class1.plot(kind="bar",color=["purple","blue","yellow"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic["Age"].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
"""
your comments here

"""
graf=sns.histplot(x=titanic.Age, kde=True)
graf.axvline(x=titanic.Age.mean(), c="red", label="mean") 
graf.axvline(x=titanic.Age.std(), c="green", label="std")
graf.axvline(x=titanic.Age.max(), c="blue", label="ValorMáximo")
graf.axvline(x=titanic.Age.min(), c="blue", label="ValorMímino") 
graf.axvline(x=titanic.Age.dropna().quantile(.25), c="grey", label="25%")
graf.axvline(x=titanic.Age.dropna().quantile(.50), c="grey", label="50%")
graf.axvline(x=titanic.Age.dropna().quantile(.75), c="grey", label="75%")
plt.legend();

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
we are able to see all the statistic values of Age with the exception of the total count. we can appreciate that over the 75% of the passengers were under 40yo, more that 25% between 20 and 30...
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
graf=sns.histplot(x=titanic.Age, kde=True)
graf.axvline(x=titanic.Age.mean(), c="red", label="mean") 
graf.axvline(x=titanic.Age.std(), c="green", label="std")
graf.axvline(x=titanic.Age.max(), c="blue", label="ValorMáximo")
graf.axvline(x=titanic.Age.min(), c="blue", label="ValorMímino") 
graf.axvline(x=titanic.Age.dropna().quantile(.25), c="grey", label="25%")
graf.axvline(x=titanic.Age.dropna().quantile(.50), c="grey", label="50%")
graf.axvline(x=titanic.Age.dropna().quantile(.75), c="grey", label="75%")
plt.legend();

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
it provides the number of people with the same age .
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(x=titanic.Fare, y=titanic.Age);
# your code here

# %%
# Method 2 - seaborn
sns.jointplot(data=titanic, x= "Fare", y= "Age")


# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.pairplot(titanic)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.violinplot(x=titanic.Pclass, y=titanic.Age);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
gender=sns.FacetGrid(titanic,col="Age")

g.map_dataframe(sns.scatterplot, x="Age", y="titanic.Age.value_counts()", hue="Gender")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9f3341cbd782> in <module>
#       1 # your code here
# ----> 2 gender=sns.FacetGrid(titanic,col="Age")
#       3
#       4 g.map_dataframe(sns.scatterplot, x="Age", y="titanic.Age.value_counts()", hue="Gender")
#
# NameError: name 'sns' is not defined
