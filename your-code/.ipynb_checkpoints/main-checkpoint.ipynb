# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# IMPORT LIBRERY

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# THEN PIP INSTALL

# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# !pip install pandas

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# TO IMPORT A DATASET

fitbit = pd.read_csv('../data/Fitbit2.csv')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# RANDOM SAMPLE OF A DATASET

fitbit.sample(3)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 361  2016-05-02            2989  13236      9.98      12              770.0
# 285  2016-02-16            2927   7995      5.98      15              802.0
# 318  2016-03-20            2731   6754      5.02       1              564.0
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 361                     234                      8                   38
# 285                     231                     34                   16
# 318                     315                      0                    0
#
#      Activity Calories  ...  Distance_miles     Days  Days_encoded  \
# 361               1477  ...        6.201283   Monday           0.0
# 285               1347  ...        3.715799  Tuesday           1.0
# 318               1237  ...        3.119282   Sunday           6.0
#
#      Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# ...

# %%
# AVERAGE STEPS BY MONTH

# ONE WAY
av_steps = fitbit.groupby("Months_encoded").agg({"Steps": "mean"})

# OR ANOTHER
pd.DataFrame(fitbit.groupby("Months_encoded")["Steps"].mean());

# %%
# POT AVG STEPS BY MONTH

av_steps.plot(kind="bar", stacked=True, colormap='Paired');

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# WE ARE GONNA CHANGE 0 FOR WORK DAY & 1 FOR WEEKDAY

def cambia_wow(x):
    if x == 0:
        return "Work days"
    elif x == 1:
        return "Weekend"
    
# ONCE WE HAVE THE FUNCTION, WE ARE GONNA CALL IT & CREATE A NEW ROW WITH THE NEW STRINGS
    
fitbit["WoW"] = fitbit.Work_or_Weekend.apply(cambia_wow)

# %%
# AVG STEPS BY WORK/WEEKEND

av_WoW = fitbit.groupby("WoW").agg({"Steps": "mean"});

# %%
# AVG STEPS BY WORK/WEEKEND

av_WoW.plot(kind="bar", stacked=True, colormap='Paired');

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# WE ARE GONNA CHECK THE CORRELATION OF OUR DATASET

fitbit.corr()
# Out:
#                             Calorie burned     Steps  Distance    Floors  \
# Calorie burned                    1.000000  0.255305  0.292790  0.130757
# Steps                             0.255305  1.000000  0.779678  0.306511
# Distance                          0.292790  0.779678  1.000000  0.382940
# Floors                            0.130757  0.306511  0.382940  1.000000
# Minutes Sedentary                 0.125353  0.076906  0.160632  0.057812
# Minutes Lightly Active            0.209540  0.393010  0.455272 -0.085992
# Minutes Fairly Active             0.188256  0.303244  0.348113  0.278408
# Minutes Very Active               0.197881  0.571452  0.759310  0.399503
# Activity Calories                -0.130758 -0.160568 -0.246853 -0.155532
# MinutesOfSleep                    0.011485  0.130986  0.129442  0.069464
# MinutesOfBeingAwake               0.041999  0.124846  0.130447  0.064587
# NumberOfAwakings                  0.030490  0.106591  0.091095  0.043459
# ...

# %%
# LOOP TO PLOT 3 SCATTER PLOTS

mins = ("Minutes Lightly Active","Minutes Very Active","Minutes Sedentary")

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20,15))

for i in range(3):
    sns.scatterplot(x=mins[i], y="Steps", data=fitbit, vmin=0, ax=axs[i])

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# IMPORT A NEW DATASET

titanic = pd.read_csv('../data/titanic.csv')

# %%
# LET'S ADD A BOOLEAN FOR MALE & FEMALE IN ORDER TO STUDY THIS CORRELATION TOO

def cambia_gender(x):
    if x == "male":
        return 1
    elif x == "female":
        return 0
    
# ONCE WE HAVE THE FUNCTION, WE ARE GONNA CALL IT & CREATE A NEW ROW WITH THE NEW BOOLEAN
    
titanic["M/F"] = titanic.Gender.apply(cambia_gender)

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# EXPLORE

titanic.sample(3)
# Out:
#      PassengerId  Survived  Pclass  \
# 926          927       NaN       3
# 522          523       0.0       3
# 842          843       1.0       1
#
#                                                  Name  Gender        Age  \
# 926  Katavelas, Mr. Vassilios (Catavelas Vassilios")"    male  18.500000
# 522                                Lahoud, Mr. Sarkis    male  27.749836
# 842                           Serepeca, Miss. Augusta  female  30.000000
#
#      Parch  Ticket     Fare Cabin Embarked  M/F
# 926      0    2682   7.2292    U0        C    1
# 522      0    2624   7.2250    U0        C    1
# 842      0  113798  31.0000    U0        C    0

# %%
# LET'S DELETE SIBSP COLUMN IN ORDER TO CLEAN OUR DATASET

del titanic['SibSp']

# %%
# MOOOORE EXPLORATION

titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
#  12  M/F          1309 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 133.1+ KB

# %%
# EVEN MOOOOORE EXPLORATION

titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
# M/F             0.013406 -0.543351  0.124617  0.073578 -0.109609 -0.213125
#
#                  Fare       M/F
# PassengerId  0.031128  0.013406
# Survived     0.257307 -0.543351
# Pclass      -0.558683  0.124617
# Age          0.171355  0.073578
# SibSp        0.160349 -0.109609
# Parch        0.221635 -0.213125
# Fare         1.000000 -0.185681
# ...

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES

titanic.select_dtypes(include=['float64','int64','bool'])
# Out:
#       PassengerId  Survived  Pclass        Age  Parch      Fare  M/F
# 0               1       0.0       3  22.000000      0    7.2500    1
# 1               2       1.0       1  38.000000      0   71.2833    0
# 2               3       1.0       3  26.000000      0    7.9250    0
# 3               4       1.0       1  35.000000      0   53.1000    0
# 4               5       0.0       3  35.000000      0    8.0500    1
# ...           ...       ...     ...        ...    ...       ...  ...
# 1304         1305       NaN       3  29.513190      0    8.0500    1
# 1305         1306       NaN       1  39.000000      0  108.9000    0
# 1306         1307       NaN       3  38.500000      0    7.2500    1
# 1307         1308       NaN       3  29.513190      0    8.0500    1
# 1308         1309       NaN       3  25.315435      1   22.3583    1
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES

titanic.select_dtypes(exclude=['float64','int64'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# HOW TO SET A PLOT

sns.set(rc={"figure.figsize": (12.,6.)})
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# TO SEE THE DISTRIBUTION OF AGE IN THE TITANIC

sns.histplot(x=titanic.Age, bins=75, kde=True);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# CREATE A SUBPLOT AND INDEX 3 PLOTS

fig, axs = plt.subplots(nrows=1, ncols=3)

# AXIS ALLOW US TO PLACE EACH PLOT IN A EXACT PLACE
# BINS HELP US TO UNDERSTAND THE DATA

sns.histplot(x=titanic.Age, bins=10, ax=axs[0])
sns.histplot(x=titanic.Age, bins=20, ax=axs[1])
sns.histplot(x=titanic.Age, bins=50, ax=axs[2]);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
# LESS BINS MAKES IT MORE DIFFICULT TO GET INTO DETAIL
# MORE BINS MAKES IT MORE EASY TO UNDERSTAND HOW MUCH PEOPLE ARE FROM EACH EXACT AGE

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# TO SEE THE DISTRIBUTION OF THE AGE

sns.histplot(x=titanic.Age, bins=40, kde=True);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# SUBPLOT TO UNDERSTAND THE THREE WAYS

fig, axs = plt.subplots(nrows=1, ncols=2)


# THE WORST WAY TO SEE IT :(
titanic["Gender"].value_counts().plot(kind="pie", title= "GENDER",ax=axs[0]);

# BETTER WAY TO SEE IT :)
titanic["Gender"].value_counts().plot(kind='bar',title='GENDER',ax=axs[1]);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# A WAY TO SEE THE DIFFERENT CLASS

titanic["Pclass"].value_counts().plot(kind='bar',title='CLASS');

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# BOXPLOT COULD BE ONE OF THE BEST WAYS TO DO IT

sns.boxplot(x="Age", data=titanic);

# %%
# BOXPLOT IS A GOOD WAY TO SEE HOW DIFFERENT AGES 
# WE CAN SEE QUARTILE (1,2,3,4) THE MEAN & THE OUTLIERS

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
# 80% OF THE PEOPLE IN THE TITANIC, WERE BETWEEN 22 AND 38

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# VIOLIN IS A REALLY GOOD WAY TO UNDERSTAND THE DISTRIBUTION

violin = sns.violinplot(x=titanic.Age)
violin.axvline(x=titanic.Age.median());

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
# WE CAN ALSO SEE THE DISTRIBUTION IN BOTH ENDS (YOUNG & OLD PEOPLE)

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# SUBPLOT TO UNDERSTAND TWO WAYS

fig, axs = plt.subplots(nrows=1, ncols=2)

# SEABORN CORRELATION
sns.scatterplot(x="Age", y="Fare",data=titanic,ax=axs[0]);

# MATPLOTLIB CORRELATION
sns.catplot(x="Age", y="Fare", data=titanic,ax=axs[1]);
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/seaborn/categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# LETS CHECK OUR DATA CORRELATION

corr = titanic.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     Parch      Fare  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325  0.008942  0.031128
# Survived       -0.005007  1.000000 -0.338481 -0.065376  0.081629  0.257307
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.018322 -0.558683
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.145488  0.171355
# Parch           0.008942  0.081629  0.018322 -0.145488  1.000000  0.221635
# Fare            0.031128  0.257307 -0.558683  0.171355  0.221635  1.000000
# M/F             0.013406 -0.543351  0.124617  0.073578 -0.213125 -0.185681
#
#                   M/F
# PassengerId  0.013406
# Survived    -0.543351
# Pclass       0.124617
# Age          0.073578
# Parch       -0.213125
# Fare        -0.185681
# M/F          1.000000

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   Parch        1309 non-null   int64
#  7   Ticket       1309 non-null   object
#  8   Fare         1309 non-null   float64
#  9   Cabin        1309 non-null   object
#  10  Embarked     1309 non-null   object
#  11  M/F          1309 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
#LET'S DEFINE OUR MATRIX

# PASSENGERID
# SURVIVED 
# PCLASS
# AGE
# SIBSP SibSp = (number of siblings on board) / (number of spouse on board)
# PARCH = (number of Parents on board) / (number of Children on board)
# FARE = (port of embarking)

sns.heatmap(corr,
            mask = np.triu(np.ones_like(corr, 
            dtype=bool)),
            cmap= sns.diverging_palette(0, 100, 
            as_cmap=True),
            square=True,
            linewidth=0.5,
            vmax=1,
            cbar_kws={"shrink": .5});

# %% [markdown]
# #### What are the most correlated features?

# %%
# THERE IS A BIG CORRELATION BETWEEN THE FARE AND THE SURVIVAL
# THE TICKET AND THE SURVIVAL

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# BOXPLOT IS THE BEST WAY TO DO IT

sns.boxplot(x="Pclass", y="Age", data=titanic);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# KDEPLOT HELP US TO BETTER UNDERSTAND THE DISTRIBUTION BETWEEN AGE AND GENDER

sns.kdeplot(x=titanic.Age, hue=titanic.Gender, fill=True);

# %%
# ME HA GUSTADO MUCHO ESTE "LAB" AUNQUE ME HAN QUEDADO BASTANTES DUDAS A RESOLVER CON RESPECTO A LA CORRELACIÓN

# 1. HE AÑADIDO UNA COLUMNA DE GENERO (BOOLEANO) CON LA INTENCIÓN DE INCLUIRLO EN EN LA CORRELACIÓN
# 2. NO ENTIENDO SI PYTHON ES CAPAZ DE ASOCIAR PCLASS (1,2,3) A OTRAS VARIABLES COMO: AGE/SURVIVED/TICKET PRICE
# 2.1 CREÍ QUE ENCONTRARÍA LA CORRELACIÓN MÁS ALTA AQUÍ
# 3. HE RETIRADO LA COLUMNA SIBSP CON LA IDEA DE LIMPIAR EL DATASET 

# MAÑANA SIGO DANDO LA CHAPA CON ESTE ASUNTO :)

# GAAAAAAAS
