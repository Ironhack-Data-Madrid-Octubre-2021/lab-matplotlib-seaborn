# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
# Your Code Here
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit = pd.read_csv("../data/Fitbit2.csv")

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here
pd.DataFrame(fitbit.groupby(["Months_encoded"])["Steps"].mean())
# Out:
#                        Steps
# Months_encoded
# 1                9892.064516
# 2                8922.866667
# 3               10312.935484
# 4               13079.033333
# 5               10620.096774
# 6               12536.166667
# 7                9193.322581
# 8               11584.774194
# 9                9191.333333
# 10               8272.451613
# 11               9467.466667
# 12               8470.064516

# %%
sns.barplot(x='Months_encoded', y='Steps', data=fitbit);

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
fitbit.groupby(['Work_or_Weekend']).agg({'Steps':'mean'})
# Out:
#                         Steps
# Work_or_Weekend
# 0                10064.238095
# 1                10144.572519

# %%
sns.barplot(x='Work_or_Weekend', y='Steps', data=fitbit, palette='magma')
# Out:
# <AxesSubplot:xlabel='Work_or_Weekend', ylabel='Steps'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
fitbit.corr()
# Out:
#                             Calorie burned     Steps  Distance    Floors  \
# Calorie burned                    1.000000  0.255305  0.292790  0.130757
# Steps                             0.255305  1.000000  0.779678  0.306511
# Distance                          0.292790  0.779678  1.000000  0.382940
# Floors                            0.130757  0.306511  0.382940  1.000000
# Minutes Sedentary                 0.125353  0.076906  0.160632  0.057812
# Minutes Lightly Active            0.209540  0.393010  0.455272 -0.085992
# Minutes Fairly Active             0.188256  0.303244  0.348113  0.278408
# Minutes Very Active               0.197881  0.571452  0.759310  0.399503
# Activity Calories                -0.130758 -0.160568 -0.246853 -0.155532
# MinutesOfSleep                    0.011485  0.130986  0.129442  0.069464
# MinutesOfBeingAwake               0.041999  0.124846  0.130447  0.064587
# NumberOfAwakings                  0.030490  0.106591  0.091095  0.043459
# ...

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20,15))
sns.scatterplot(x='Minutes Lightly Active', y='Steps', data=fitbit, ax=axs[0]);
sns.scatterplot(x='Minutes Very Active', y='Steps', data=fitbit, ax=axs[1]);
sns.scatterplot(x='Minutes Sedentary', y='Steps', data=fitbit, ax=axs[2]);

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20,15))
lista = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']
for i in range(3):
    for x in lista:
       sns.scatterplot(x=lista[i], y='Steps', data=fitbit, ax=axs[i]) ;

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv("../data/titanic.csv")

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 81            82       1.0       3
# 88            89       1.0       1
# 705          706       0.0       2
# 683          684       0.0       3
# 775          776       0.0       3
#
#                                                Name  Gender   Age  SibSp  \
# 81                      Sheerlinck, Mr. Jan Baptist    male  29.0      0
# 88                       Fortune, Miss. Mabel Helen  female  23.0      3
# 705  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0      0
# 683                     Goodwin, Mr. Charles Edward    male  14.0      5
# 775         Myhrman, Mr. Pehr Fabian Oliver Malkolm    male  18.0      0
#
#      Parch   Ticket    Fare        Cabin Embarked
# 81       0   345779    9.50           U0        S
# 88       2    19950  263.00  C23 C25 C27        S
# 705      0   250655   26.00           U0        S
# 683      2  CA 2144   46.90           U0        S
# 775      0   347078    7.75           U0        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['float64','int64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(exclude=['float64','int64','bool'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
plt.style.use('classic')

# %%
titanic.sample(5)
# Out:
#       PassengerId  Survived  Pclass  \
# 823           824       1.0       3
# 1055         1056       NaN       2
# 896           897       NaN       3
# 904           905       NaN       2
# 426           427       1.0       2
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 823                            Moor, Mrs. (Beila)  female  27.0      0      1
# 1055                Peruschitz, Rev. Joseph Maria    male  41.0      0      0
# 896                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# 904                          Howard, Mr. Benjamin    male  63.0      1      0
# 426   Clarke, Mrs. Charles V (Ada Maria Winfield)  female  28.0      1      0
#
#       Ticket    Fare Cabin Embarked
# 823   392096  12.475  E121        S
# 1055  237393  13.000    U0        S
# 896     7538   9.225    U0        S
# 904    24065  26.000    U0        S
# 426     2003  26.000    U0        S

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20,15))
sns.histplot(data=titanic, x="Age", bins=10, ax=axs[0])
sns.histplot(data=titanic, x="Age", bins=20, ax=axs[1])
sns.histplot(data=titanic, x="Age", bins=50, ax=axs[2])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Cuántas más bins haya más distribuida la info estará
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic['Gender'].value_counts().plot(kind = 'bar', title = 'Titanic Passengers Gender');

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x='Gender', data=titanic)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x='Pclass', data=titanic, palette='magma')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(y='Age', data=titanic)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
"""
Boxplot me permite ver como se distribuye la edad de los pasajeros en cuartiles de forma clara
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
La edad de los pasajeros esta muy concentrada entre los 20 y 40 años
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The passengers in Titanic were mostly concentrated between the ages of 20 -40 years, same info as the graph above
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic['Fare'], titanic['Age'])

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(x='Fare', y='Age', data=titanic)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr = titanic.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
mascara = np.triu(np.ones_like(corr, dtype=bool))
colour_map= sns.diverging_palette(20, 40, as_cmap=True)
sns.heatmap(corr,
            mask = mascara,
            cmap = colour_map,
            square = True,
            linewidth = 0.5,
            annot=True,
            vmax = 1,
            cbar_kws= {'shrink': 0.5}
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated variables are 'Pclass' & 'Fare' with a negative correlation of -0.56
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x='Pclass', y='Age', data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.kdeplot(x=titanic.Age, hue=titanic.Gender, fill=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>
