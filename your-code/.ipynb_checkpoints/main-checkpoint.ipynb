# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
# Your Code Here

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here

# %%
g1 = fitbit.groupby("Months_encoded").agg({"Steps": "median",})

# %%
g1.plot(kind="bar", figsize=(12,6), title="Meses")
# Out:
# <AxesSubplot:title={'center':'Meses'}, xlabel='Months_encoded'>

# %%
plt.savefig("../../Figures/g1.png", dpi=1000)

# %%
g11 = fitbit.groupby("Months_encoded").agg({"Steps": "mean",})

# %%
g11.plot(kind="bar", figsize=(12,6), title="Meses")
# Out:
# <AxesSubplot:title={'center':'Meses'}, xlabel='Months_encoded'>

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here

# %%
g2 = fitbit.groupby("Work_or_Weekend").agg({"Steps": "mean",})

# %%
g2.plot(kind="bar", figsize=(12,6), title="Semanas y findes")
# Out:
# <AxesSubplot:title={'center':'Semanas y findes'}, xlabel='Work_or_Weekend'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,4));

x = ["Minutes Lightly Active","Minutes Fairly Active","Minutes Very Active"]

for i in range(0,3):
    sns.scatterplot(data=fitbit, x = x[i], y="Steps", ax=axs[i])

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
titanic.select_dtypes(include="int64").columns
# Out:
# Index(['PassengerId', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
titanic.select_dtypes(include="float64",).head()
# Out:
#    Survived   Age     Fare
# 0       0.0  22.0   7.2500
# 1       1.0  38.0  71.2833
# 2       1.0  26.0   7.9250
# 3       1.0  35.0  53.1000
# 4       0.0  35.0   8.0500

# %%
titanic.select_dtypes(include="object").head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')

# %%
plt.rcParams["figure.figsize"] = (12,6)

# %%
sns.set({"figure.figsize":(12,6)})

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
aq = sns.histplot(x=titanic.Age, bins=10)

# %%
sns.histplot(x=titanic.Age, bins=20)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x=titanic.Age, bins=50)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""
Cuantos más bins es más detallado. Cuando hay menos bins se agrupa en menores grupos de rangos de edad más amplios.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# Ya he usado seaborn así que lo hago aquí con Matplotlib
titanic.Age.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic["Gender"].value_counts().plot(kind="bar", figsize=(12,6), title="Géneros")
plt.xticks(rotation=45);

# %%
sns.countplot(x=titanic.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic["Pclass"].unique()
# Out:
# array([3, 1, 2])

# %%
sns.countplot(x=titanic.Pclass)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
La mediana de edad se encontraba en torno a los 28 años.
Existe entre los 22 y los 37 años se encontraba cerca de un 50% de la población del barco.
Y los menos de 22 represnetaban un 25% al igual que los mayores de 37.
Además las personas mayores de 60 años se podían considerar valores atípicos.
""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
graf = sns.histplot(x=titanic.Age, kde=True) # Hemos guardado el gráfico como una variable
graf.axvline(x=titanic.Age.mean(), c="red", label="mean") #Antes había puesto dropna pero no hace falta
graf.axvline(x=titanic.Age.median(), c="green", label="median")
graf.axvline(x=titanic.Age.max(), c="blue", label="ValorMáximo") #Sobre la vertical marcamos eje

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Que existe una asimetría pósitiva en la distribución de la edad.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
plt.scatter(x=titanic.Age, y=titanic.Fare);

# %%
sns.scatterplot(x="Age", y="Fare",data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
mascara = np.triu(np.ones_like(corr, dtype=bool)) 
color_map = sns.diverging_palette(0, 10, as_cmap=True) 
sns.heatmap(corr,  
            mask = mascara,
            cmap=color_map,
            square=True, 
            linewidth=0.5, 
            vmax=1,
            cbar_kws={"shrink": .5} 
);

# %%
"""
PClass y Fare
PClass y Age 
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.catplot(x="Pclass", y="Age", data=titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col="Gender")
g.map(sns.histplot, "Age")
